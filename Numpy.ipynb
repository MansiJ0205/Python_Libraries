# %%
print("hello world")
# Out:
# hello world

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
list =["pride",10,20,3.14]

# %%
print(list)
# Out:
# ['pride', 10, 20, 3.14]

# %%
arr =np.array(list)
print(arr)
# Out:
# ['pride' '10' '20' '3.14']

# %%
list1 =[10,20,30,43]

# %%
arr =np.array(list1)
print(arr)
# Out:
# [10 20 30 43]

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr.shape
# Out:
# (4,)

# %%
list2=[[1,2,3],[7,8,9],[11,12,13]]
arr=np.array(list2)
print(arr)
# Out:
# [[ 1  2  3]
#  [ 7  8  9]
#  [11 12 13]]

# %%
arr.shape
# Out:
# (3, 3)

# %%
arr[1][2]
# Out:
# np.int64(9)

# %%
arr[2][2]
# Out:
# np.int64(13)

# %%
arr.reshape(9,1)
# Out:
# array([[ 1],
#        [ 2],
#        [ 3],
#        [ 7],
#        [ 8],
#        [ 9],
#        [11],
#        [12],
#        [13]])

# %%
arr.reshape(1,9)
# Out:
# array([[ 1,  2,  3,  7,  8,  9, 11, 12, 13]])

# %%
lst=[[1,2,3,4],[4,5,6,7],[7,8,9,10]]
arr=np.array(lst)
print(arr)
# Out:
# [[ 1  2  3  4]
#  [ 4  5  6  7]
#  [ 7  8  9 10]]

# %%
#Indexing in Numpy - Arrays
arr[2]
# Out:
# array([ 7,  8,  9, 10])

# %%
arr[0:,:]
# Out:
# array([[ 1,  2,  3,  4],
#        [ 4,  5,  6,  7],
#        [ 7,  8,  9, 10]])

# %%
arr[:2,1:3]
# Out:
# array([[2, 3],
#        [5, 6]])

# %%
arr[:-2,-1:-3]
# Out:
# array([], shape=(1, 0), dtype=int64)

# %%
arr[-2:,-3:-1]
# Out:
# array([[5, 6],
#        [8, 9]])

# %%
arr[-2:,-2:0]
# Out:
# array([], shape=(2, 0), dtype=int64)

# %%
arr[-2:,-1:]
# Out:
# array([[ 7],
#        [10]])

# %%
np.arange
# Out:
# <function numpy.arange>

# %%
array1=np.random.randint(0,100, 5)
print(array1)
# Out:
# [ 0  4 89 23 94]

# %%
array2=np.random.randint(-200,-100, 5)
print(array2)
# Out:
# [-121 -104 -107 -111 -156]

# %%
np.concatenate([array1,array2]).reshape(2,5)
# Out:
# array([[   0,    4,   89,   23,   94],
#        [-121, -104, -107, -111, -156]], dtype=int32)
